# %%
from sunpy.net import Fido, attrs as a

res = Fido.search(a.Time('2025-03-01T10:24:00', '2025-03-01T10:25:00'),
                  a.jsoc.Series('hmi.M_720s'),
                  a.jsoc.Notify('mgjeon@khu.ac.kr'))
res
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object>
# Results from 1 Provider:
#
# 1 Results from the JSOCClient:
# Source: http://jsoc.stanford.edu
#
#          T_REC          TELESCOP   INSTRUME   WAVELNTH CAR_ROT
# ----------------------- -------- ------------ -------- -------
# 2025.03.01_10:24:00_TAI  SDO/HMI HMI_COMBINED   6173.0    2294

# %%
type(res)
# Out:
# sunpy.net.fido_factory.UnifiedResponse

# %%
files = Fido.fetch(res, path='./data')
files
# Out:
# Export request pending. [id=JSOC_20250314_000512, status=2]
# Waiting for 0 seconds...
# 1 URLs found for download. Full request totalling 14MB
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# <parfive.results.Results object>
# ['data/hmi.m_720s.20250301_102400_TAI.3.magnetogram.fits']

# %%
from sunpy.map import Map
from matplotlib.colors import Normalize

# %%
smap = Map(files[0])
smap.rotate().peek(norm=Normalize(vmin=-100, vmax=100))
